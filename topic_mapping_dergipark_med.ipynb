# %% [markdown]
# <a href="https://colab.research.google.com/github/zypchn/med-data-tr/blob/main/topic_mapping_dergipark_med.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers -q

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import copy
from transformers import pipeline
from concurrent.futures import ProcessPoolExecutor, as_completed, ThreadPoolExecutor
from typing import List, Dict
import re

# %%
f = open("journals.json")   # list of all journal names
journals = json.load(f)
len(journals)
# Out:
# 2952

# %%
# Cleaning journal names to prevent mis-classification

records = []
for key, value in journals.items():
  set_name = key
  title = value

  pattern = r'\b\w*(?:Üniversite|Fakülte|Enstitü|Dergi|University|Faculty|Institution|Journal)\w*\b'
  cleaned_title = re.sub(pattern, '', title)
  cleaned_title = re.sub(r'\s+', ' ', cleaned_title).strip()
  rec = {
      "set_name": key,
      "title": cleaned_title if len(cleaned_title) != 0 else title
  }
  records.append(rec)

# %%
df = pd.DataFrame.from_records(records, index=None)
df.head()
# Out:
#    set_name                       title
# 0   mulkiye                     Mülkiye
# 1    yerblm     Cumhuriyet Yerbilimleri
# 2  marubsed  Para ve Sermaye Piyasaları
# 3   marusbd    Marmara Siyasal Bilimler
# 4   marustd             Sanat - Tasarım

# %%
df.shape      # matches the count of initial records
# Out:
# (2952, 2)

# %%
# topics generated by claude.AI

topics = [
    "Mühendislik, Teknoloji ve Fen Bilimleri",
    "Tıp ve Sağlık Bilimleri",
    "Sanat, Tasarım ve Mimarlık",
    "Ekonomi ve İşletme",
    "Spor Bilimleri",
    "Hukuk",
    "Tarih ve Coğrafya",
    "Dil ve Edebiyat",
    "Teoloji ve Din Araştırmaları",
    "Yaşam ve Çevre Bilimleri",
    "Siyaset ve Uluslararası İlişkiler",
    "Psikoloji ve Davranış Bilimleri",
    "İletişim ve Medya Çalışmaları",
    "Eğitim",
    "Sosyal Bilimler"
]

# %%
classifier = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli")

# %%
res = classifier(
      records[12]["title"],
      candidate_labels=topics)
records[12]["title"], res["labels"][0], res["scores"][0]
# Out:
# ('Marmara İktisadi ve İdari Bilimler',
#  'Ekonomi ve İşletme',
#  0.9570614099502563)

# %%
# Topic mapping with parallel processing

class TopicMapper:
  def __init__(self, max_workers: int=3):
    self.max_workers = max_workers
    self.records_topics = []

  def _get_topic(self, record: Dict, classifier, topics: List) -> None:
    try:
      set_name = record["set_name"]
      title = record["title"]
      res = classifier(title, candidate_labels=topics)
      topic = res["labels"][0]
      topic_prob = res["scores"][0]
      rec = {
          "set_name": set_name,
          "title": title,
          "topic": topic,
          "topic_prob": topic_prob
      }
      self.records_topics.append(rec)
      print(f"topic extraction is successful for {title}")
    except Exception as e:
      print(e)

  def get_all_topics(self, records: List[Dict], classifier, topics: List) -> List[Dict]:
        with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            futures = [
                executor.submit(self._get_topic, record, classifier, topics)
                for record in records
            ]

            for future in as_completed(futures):
                try:
                    future.result()
                except Exception as e:
                    print(f"Thread error: {e}")

        return self.records_topics

# %%
mapper = TopicMapper(max_workers=10)
results = mapper.get_all_topics(records, classifier, topics)

# %%
len(results)    # matches the count of initial records
# Out:
# 2952

# %%
df = pd.DataFrame.from_records(results, index=None)
df.head()
# Out:
#    set_name                                              title  \
# 0  maruaebd            Marmara Atatürk Eğitim Eğitim Bilimleri
# 1   maruaad  Marmara Avrupa Araştırmaları Avrupa Araştırmaları
# 2   marusbd                           Marmara Siyasal Bilimler
# 3    marumj                                    Marmara Medical
# 4   marusad                        Marmara Sosyal Araştırmalar
#
#                                topic  topic_prob
# 0                             Eğitim    0.838757
# 1  Siyaset ve Uluslararası İlişkiler    0.208243
# 2                    Sosyal Bilimler    0.863213
# 3            Tıp ve Sağlık Bilimleri    0.454380
# 4                    Sosyal Bilimler    0.712313

# %%
df.to_pickle("topic_mappings.pkl")

# %%
topic_df = pd.read_pickle("topic_mappings.pkl")
topic_df.head()
# Out:
#    set_name                                              title  \
# 0  maruaebd            Marmara Atatürk Eğitim Eğitim Bilimleri
# 1   maruaad  Marmara Avrupa Araştırmaları Avrupa Araştırmaları
# 2   marusbd                           Marmara Siyasal Bilimler
# 3    marumj                                    Marmara Medical
# 4   marusad                        Marmara Sosyal Araştırmalar
#
#                                topic  topic_prob
# 0                             Eğitim    0.838757
# 1  Siyaset ve Uluslararası İlişkiler    0.208243
# 2                    Sosyal Bilimler    0.863213
# 3            Tıp ve Sağlık Bilimleri    0.454380
# 4                    Sosyal Bilimler    0.712313

# %%
topic_df.shape
# Out:
# (2952, 4)

# %%
counts = topic_df["topic"].value_counts()
counts
# Out:
# topic
# Ekonomi ve İşletme                         414
# Sosyal Bilimler                            386
# Eğitim                                     338
# Tıp ve Sağlık Bilimleri                    321
# Mühendislik, Teknoloji ve Fen Bilimleri    302
# İletişim ve Medya Çalışmaları              230
# Yaşam ve Çevre Bilimleri                   185
# Dil ve Edebiyat                            134
# Hukuk                                      131
# Siyaset ve Uluslararası İlişkiler          122
# Psikoloji ve Davranış Bilimleri             91
# Teoloji ve Din Araştırmaları                85
# Sanat, Tasarım ve Mimarlık                  79
# Tarih ve Coğrafya                           70
# Spor Bilimleri                              64
# Name: count, dtype: int64

# %%
# keeping these for another project
"""
included_topics = [
    "Tıp ve Sağlık Bilimleri",
    "Ekonomi ve İşletme",
    "Mühendislik, Teknoloji ve Fen Bilimleri"

    "Tarih ve Coğrafya",
    "Sanat, Tasarım ve Mimarlık",
    "Dil ve Edebiyat"
]
"""

# medical
med = ["Tıp ve Sağlık Bilimleri"]

# %%
selected_journals_df = topic_df[topic_df["topic"].isin(med)]

# %%
selected_journals_df.head()
# Out:
#           set_name                       title                    topic  \
# 3           marumj             Marmara Medical  Tıp ve Sağlık Bilimleri
# 13    iucerrahpasa              Cerrahpaşa Tıp  Tıp ve Sağlık Bilimleri
# 16           iujfp  of of Pharmacy of Istanbul  Tıp ve Sağlık Bilimleri
# 28        iuonkder               Türk Onkoloji  Tıp ve Sağlık Bilimleri
# 44  adiyamansaglik   Adıyaman Sağlık Bilimleri  Tıp ve Sağlık Bilimleri
#
#     topic_prob
# 3     0.454380
# 13    0.690656
# 16    0.418258
# 28    0.795952
# 44    0.778775

# %%
f = open("tur_records_filtered.json")     # previously filtered data (not by topic)
data = json.load(f)

records = []
def convert_to_dict(data):
  for d in data:
    rec = {
        "set_name": d[0],
        "year": d[1],
        "title": d[2],
        "dergipark_url": d[3],
        "pdf_url": d[4]
    }
    records.append(rec)

convert_to_dict(data)

# %%
rec_df = pd.DataFrame.from_records(records, index=None)
rec_df.head()
# Out:
#   set_name  year                                              title  \
# 0  mulkiye  2023  Kapitalizmin Kurucu Dinamizmi Olarak Göç Olgus...
# 1  mulkiye  2022                 Prof. Dr. Tuncer Bulutay’ı Tanımak
# 2  mulkiye  2022  Eril Tahakküm, Toplumsal Cinsiyet ve Gazetecil...
# 3  mulkiye  2022  NEOLİBERAL EMEK PİYASASINDA BİREYCİLİK VE BEYA...
# 4  mulkiye  2023  ‘YÜZYIL’LIK SERENCAM: BAŞKENT ANKARA’NIN DÖNÜŞ...
#
#                                        dergipark_url  \
# 0  https://dergipark.org.tr/tr/pub/mulkiye/issue/...
# 1  https://dergipark.org.tr/tr/pub/mulkiye/issue/...
# 2  https://dergipark.org.tr/tr/pub/mulkiye/issue/...
# 3  https://dergipark.org.tr/tr/pub/mulkiye/issue/...
# 4  https://dergipark.org.tr/tr/pub/mulkiye/issue/...
#
#                                              pdf_url
# 0  https://dergipark.org.tr/tr/download/article-f...
# 1  https://dergipark.org.tr/tr/download/article-f...
# 2  https://dergipark.org.tr/tr/download/article-f...
# 3  https://dergipark.org.tr/tr/download/article-f...
# 4  https://dergipark.org.tr/tr/download/article-f...

# %%
rec_df.shape
# Out:
# (244868, 5)

# %%
set_names = list(selected_journals_df["set_name"])
topic_filtered_records = rec_df[rec_df["set_name"].isin(set_names)]

# %%
topic_filtered_records.shape
# Out:
# (24136, 5)

# %%
topic_filtered_records.head()
# Out:
#           set_name  year                                              title  \
# 1242  iucerrahpasa  2019  A 16-Year Analysis of Antifungal Susceptibilit...
# 1243  iucerrahpasa  2019  Factors Affecting Mortality in Rapidly  Progre...
# 1244  iucerrahpasa  2019  Tedavinin Sirolimus’tan Everolimus’a değiştiri...
# 1245  iucerrahpasa  2019  Case of Rhabdomyolysis in a Patient Undergoing...
# 1246  iucerrahpasa  2019  Assessing the Consistency of Clinical Diagnosi...
#
#                                           dergipark_url  \
# 1242  https://dergipark.org.tr/tr/pub/iucerrahpasa/i...
# 1243  https://dergipark.org.tr/tr/pub/iucerrahpasa/i...
# 1244  https://dergipark.org.tr/tr/pub/iucerrahpasa/i...
# 1245  https://dergipark.org.tr/tr/pub/iucerrahpasa/i...
# 1246  https://dergipark.org.tr/tr/pub/iucerrahpasa/i...
#
#                                                 pdf_url
# 1242  https://dergipark.org.tr/tr/download/article-f...
# 1243  https://dergipark.org.tr/tr/download/article-f...
# 1244  https://dergipark.org.tr/tr/download/article-f...
# 1245  https://dergipark.org.tr/tr/download/article-f...
# 1246  https://dergipark.org.tr/tr/download/article-f...

# %%
topic_filtered_records.to_pickle("topic_filtered_records.pkl")
